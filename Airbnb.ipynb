# %%
import pandas as pd
from src.helpers.airbnb_cleaning import *

# %%
df = pd.read_csv("./Resources/Airbnb_Fall_Listings.csv.gz", compression="gzip")
df[["price","neighbourhood_cleansed","room_type","accommodates","longitude","latitude","beds","bedrooms","property_type","bathrooms_text","review_scores_rating"]]
# Out:
#          price neighbourhood_cleansed        room_type  accommodates  \
# 0      $225.00          Pacific Beach  Entire home/apt             8
# 1      $113.00              Roseville     Private room             1
# 2      $258.00          Pacific Beach  Entire home/apt             7
# 3      $336.00          Pacific Beach  Entire home/apt             8
# 4      $333.00               La Jolla  Entire home/apt             3
# ...        ...                    ...              ...           ...
# 14183  $111.00             Terra Nova  Entire home/apt             4
# 14184  $145.00        Del Mar Heights  Entire home/apt             3
# 14185   $32.00            Mission Bay     Private room             2
# 14186  $173.00         Paradise Hills  Entire home/apt             6
# 14187   $56.00                Rolando     Private room             2
#
#        longitude   latitude  beds  bedrooms         property_type  \
# 0     -117.25760  32.807510   3.0       2.0       Entire bungalow
# ...

# %%
df.neighbourhood_cleansed.unique()
# Out:
# array(['Pacific Beach', 'Roseville', 'La Jolla', 'Bay Park',
#        'College Area', 'West University Heights', 'North Hills',
#        'East Lake', 'Old Town', 'Mira Mesa', 'Bird Land', 'Midtown',
#        'North City', 'Carmel Valley', 'Clairemont Mesa', 'Park West',
#        'Talmadge', 'Moreno Mission', 'Mission Bay', 'Loma Portal',
#        'Lake Murray', 'South Park', 'Torrey Pines', 'Balboa Park',
#        'Linda Vista', 'Normal Heights', 'Ocean Beach', 'Core',
#        'East Village', 'Rancho Penasquitos', 'Midtown District',
#        'Little Italy', 'University City', 'Grantville', 'Grant Hill',
#        'Mission Valley', 'Cortez Hill', 'North Clairemont',
#        'Del Mar Heights', 'Otay Ranch', 'Northwest', 'Kensington',
#        'Bay Ho', 'Webster', 'Serra Mesa', 'Sabre Springs', 'Columbia',
#        'Gaslamp Quarter', 'Marina', 'El Cerritos', 'Rancho Bernadino',
#        'Kearny Mesa', 'Memorial', 'Valencia Park', 'Encanto',
# ...

# %%
cleaned = clean_df("./Resources/Airbnb_Fall_Listings.csv.gz")
# Out:
# C:\Users\SamiS\anaconda3\envs\mlenv\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# C:\Users\SamiS\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# ...

# %%
cleaned.price.describe()
# Out:
# count    14109.000000
# mean       285.437522
# std        327.995668
# min         10.000000
# 25%        118.000000
# 50%        186.000000
# 75%        325.000000
# max       5000.000000
# Name: price, dtype: float64

# %%
cleaned.loc[cleaned['price'] >= 1000].count()
# Out:
# id                             487
# price                          487
# neighbourhood_cleansed         487
# room_type                      487
# accommodates                   487
# longitude                      487
# latitude                       487
# beds                           481
# bedrooms                       479
# property_type                  487
# availability_90                487
# minimum_nights                 487
# host_listings_count            487
# review_scores_rating           487
# review_scores_accuracy         487
# review_scores_cleanliness      487
# review_scores_checkin          487
# review_scores_communication    487
# review_scores_location         487
# review_scores_value            487
# license                        487
# host_name                      487
# listing_url                    487
# bathrooms                      487
# dtype: int64

# %%
counts = cleaned.price.value_counts()
cleaned.price.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from curses import KEY_REPLACE


for columns in df:
    print(columns)

# Target column is price
# Columns to Keep
# Out:
# id
# listing_url
# scrape_id
# last_scraped
# source
# name
# description
# neighborhood_overview
# picture_url
# host_id
# host_url
# host_name
# host_since
# host_location
# host_about
# host_response_time
# host_response_rate
# host_acceptance_rate
# host_is_superhost
# host_thumbnail_url
# host_picture_url
# host_neighbourhood
# host_listings_count
# host_total_listings_count
# host_verifications
# host_has_profile_pic
# host_identity_verified
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# latitude
# longitude
# property_type
# room_type
# accommodates
# bathrooms
# bathrooms_text
# bedrooms
# beds
# amenities
# price
# minimum_nights
# maximum_nights
# minimum_minimum_nights
# maximum_minimum_nights
# minimum_maximum_nights
# maximum_maximum_nights
# minimum_nights_avg_ntm
# maximum_nights_avg_ntm
# calendar_updated
# has_availability
# availability_30
# availability_60
# availability_90
# availability_365
# calendar_last_scraped
# number_of_reviews
# ...

# %% [markdown]
# # Columns to keep
# *   Target column is price
# # Columns to Keep
# *   Lontitude
# *   Latitude
# *   Bathrooms - Using splitting to get the number at the beginning of the string.
# *   Bedrooms
# *   Beds
# *   Neighborhoods
# *   Reviews per month
# *   Property type
# *   Room type
# *   Review scores rating
# *   Neighbourhood Cleansed
